# %% [markdown]
# # Image De-Hazing
# ## AMEF Testing: Various Clip Ranges and Gamma Levels

# %%
# %matplotlib inline
# %matplotlib notebook

import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
from plotnine import *

from sklearn.preprocessing import StandardScaler #Z-score variables

from sklearn.linear_model import LogisticRegression # Logistic Regression Model
from sklearn.tree import DecisionTreeClassifier
from sklearn.decomposition import PCA # Principle Component Analysis
from sklearn.cluster import AgglomerativeClustering # hierarchical agglomerative clustering
from sklearn.cluster import KMeans # k-means
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score #model evaluation
from sklearn.metrics import confusion_matrix, plot_confusion_matrix #model evaluation
from sklearn.metrics import silhouette_score


from sklearn.model_selection import train_test_split # simple TT split cv
from sklearn.model_selection import KFold # k-fold cv
from sklearn.mixture import GaussianMixture # EM/GMM
from sklearn.utils import shuffle

import scipy.cluster.hierarchy as sch
from matplotlib import pyplot as plt

from mizani.breaks import date_breaks
from mizani.formatters import date_format

import math

pd.set_option('display.max_rows', 100)



np.random.seed(11132009)

# %%
data = pd.read_csv("../eval_20_Jul_2021_13_36_29.csv")
data.head(7)
# Out:
#       Dataset        Filename  Size(Pixels) Method       MSE      SSIM  \
# 0  D-HAZY-MID  Adirondack_im0      17176320   HAZY  0.093500  0.686573
# 1  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.045760  0.768561
# 2  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.033644  0.816057
# 3  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.026954  0.846020
# 4  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.023657  0.862817
# 5  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.020338  0.871445
# 6  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.018654  0.874759
#
#    ClipRange  NumGamma       Time
# 0      0.000       0.0        NaN
# 1      0.005       3.0   7.339993
# 2      0.005       4.0   8.067115
# 3      0.005       5.0   8.692747
# 4      0.005       6.0   9.462002
# 5      0.005       7.0  11.543515
# 6      0.005       8.0  13.631208

# %%
crs = [0.005, 0.01, 0.015, 0.02, 0.025, 0.03]
ngs = [3.0, 4.0, 5.0, 6.0, 7.0, 8.0]

is_cr_ng = [[0 for x in range(6)] for y in range(6)] 
data_cr_ng = [[0 for x in range(6)] for y in range(6)]

is_hazy = data["Method"] == "HAZY"
data_hazy = data[is_hazy]

for i, cr in enumerate(crs):
    for j, ng in enumerate(ngs):
        is_cr_ng[i][j] = (data["ClipRange"] == cr) & (data["NumGamma"] == ng)
        data_cr_ng[i][j] = data[is_cr_ng[i][j]]



# is_amef_005 = data["Method"] == "AMEF_0.005"
# is_amef_010 = data["Method"] == "AMEF_0.01"
# is_amef_015 = data["Method"] == "AMEF_0.015"
# is_amef_mod_001 = data["Method"] == "AMEF_Modified_0.001"
# is_amef_mod_003 = data["Method"] == "AMEF_Modified_0.003"
# is_amef_mod_005 = data["Method"] == "AMEF_Modified_0.005"


# data_amef_005 = data[is_amef_005]
# data_amef_010 = data[is_amef_010]
# data_amef_015 = data[is_amef_015]
# data_amef_mod_001 = data[is_amef_mod_001]
# data_amef_mod_003 = data[is_amef_mod_003]
# data_amef_mod_005 = data[is_amef_mod_005]

# %% [markdown]
# ## Dataset Names:
# - D-HAZY-MID
# - HTTS-SYN
# - I-HAZY-NTIRE-2018
# - O-HAZY-NTIRE-2018

# %%
data_cr_ng[1][4].head()
# Out:
#         Dataset        Filename  Size(Pixels) Method       MSE      SSIM  \
# 11   D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.021232  0.858920
# 48   D-HAZY-MID    Backpack_im0      17781120   AMEF  0.022749  0.849503
# 85   D-HAZY-MID    Bicycle1_im0      17999712   AMEF  0.013459  0.901293
# 122  D-HAZY-MID       Cable_im0      16641792   AMEF  0.166506  0.592153
# 159  D-HAZY-MID  Classroom1_im0      17280000   AMEF  0.039906  0.707140
#
#      ClipRange  NumGamma       Time
# 11        0.01       7.0  11.458892
# 48        0.01       7.0  11.880043
# 85        0.01       7.0  11.762596
# 122       0.01       7.0  10.868431
# 159       0.01       7.0  11.519225

# %%
means_hazy = {
    "Dataset" : ["D-HAZY-MID",
                 "HTTS-SYN",
                 "I-HAZY-NTIRE-2018",
                 "O-HAZY-NTIRE-2018",
                 "Total"],
    "Method" : ["HAZY"] * 5,
    "ClipRange" : [0] * 5,
    "NumGamma" : [0] * 5,
    "mean_mse" : [0] * 5,
    "mean_ssim" : [0] * 5,
    "stand_dev_mse" : [0] * 5,
    "stand_dev_ssim" : [0] * 5,
}

means = [[dict(means_hazy) for x in range(6)] for y in range(6)] 

# for index, row in data_hazy.iterrows():
means_hazy["mean_mse"][4] = data_hazy["MSE"].mean()
means_hazy["mean_ssim"][4] = data_hazy["SSIM"].mean()
means_hazy["stand_dev_mse"][4] = data_hazy["MSE"].std()
means_hazy["stand_dev_ssim"][4] = data_hazy["SSIM"].std()

is_dhz = data_hazy["Dataset"] == "D-HAZY-MID"
dhz = data_hazy[is_dhz]
means_hazy["mean_mse"][0] = dhz["MSE"].mean()
means_hazy["mean_ssim"][0] = dhz["SSIM"].mean()
means_hazy["stand_dev_mse"][0] = dhz["MSE"].std()
means_hazy["stand_dev_ssim"][0] = dhz["SSIM"].std()

is_hts = data_hazy["Dataset"] == "HTTS-SYN"
hts = data_hazy[is_hts]
means_hazy["mean_mse"][1] = hts["MSE"].mean()
means_hazy["mean_ssim"][1] = hts["SSIM"].mean()
means_hazy["stand_dev_mse"][1] = hts["MSE"].std()
means_hazy["stand_dev_ssim"][1] = hts["SSIM"].std()

is_ihz = data_hazy["Dataset"] == "I-HAZY-NTIRE-2018"
ihz = data_hazy[is_ihz]
means_hazy["mean_mse"][2] = ihz["MSE"].mean()
means_hazy["mean_ssim"][2] = ihz["SSIM"].mean()
means_hazy["stand_dev_mse"][2] = ihz["MSE"].std()
means_hazy["stand_dev_ssim"][2] = ihz["SSIM"].std()

is_ohz = data_hazy["Dataset"] == "O-HAZY-NTIRE-2018"
ohz = data_hazy[is_ohz]
means_hazy["mean_mse"][3] = ohz["MSE"].mean()
means_hazy["mean_ssim"][3] = ohz["SSIM"].mean()
means_hazy["stand_dev_mse"][3] = ohz["MSE"].std()
means_hazy["stand_dev_ssim"][3] = ohz["SSIM"].std()

means_hazy = pd.DataFrame(means_hazy)
means_hazy.head()
# Out:
#              Dataset Method  ClipRange  NumGamma  mean_mse  mean_ssim  \
# 0         D-HAZY-MID   HAZY          0         0  0.125663   0.636021
# 1           HTTS-SYN   HAZY          0         0  0.041467   0.775688
# 2  I-HAZY-NTIRE-2018   HAZY          0         0  0.046588   0.603014
# 3  O-HAZY-NTIRE-2018   HAZY          0         0  0.050364   0.379695
# 4              Total   HAZY          0         0  0.064527   0.532982
#
#    stand_dev_mse  stand_dev_ssim
# 0       0.080773        0.136072
# 1       0.028023        0.119017
# 2       0.032631        0.142398
# 3       0.026709        0.201711
# 4       0.054928        0.215104

# %%
for i, cr in enumerate(crs):
    for j, ng in enumerate(ngs):
        means[i][j]["Method"] = ["AMEF"] * 5
        means[i][j]["ClipRange"] = [cr] * 5
        means[i][j]["NumGamma"] = [ng] * 5
        means[i][j]["mean_mse"] = [0] * 5
        means[i][j]["mean_ssim"] = [0] * 5
        means[i][j]["stand_dev_mse"] = [0] * 5
        means[i][j]["stand_dev_ssim"] = [0] * 5
        
        means[i][j]["mean_mse"][4] = data_cr_ng[i][j]["MSE"].mean()
        means[i][j]["mean_ssim"][4] = data_cr_ng[i][j]["SSIM"].mean()
        means[i][j]["stand_dev_mse"][0] = data_cr_ng[i][j]["MSE"].std()
        means[i][j]["stand_dev_ssim"][0] = data_cr_ng[i][j]["SSIM"].std()

        is_dhz = data_cr_ng[i][j]["Dataset"] == "D-HAZY-MID"
        dhz = data_cr_ng[i][j][is_dhz]
        means[i][j]["mean_mse"][0] = dhz["MSE"].mean()
        means[i][j]["mean_ssim"][0] = dhz["SSIM"].mean()
        means[i][j]["stand_dev_mse"][0] = dhz["MSE"].std()
        means[i][j]["stand_dev_ssim"][0] = dhz["SSIM"].std()

        is_hts = data_cr_ng[i][j]["Dataset"] == "HTTS-SYN"
        hts = data_cr_ng[i][j][is_hts]
        means[i][j]["mean_mse"][1] = hts["MSE"].mean()
        means[i][j]["mean_ssim"][1] = hts["SSIM"].mean()
        means[i][j]["stand_dev_mse"][1] = hts["MSE"].std()
        means[i][j]["stand_dev_ssim"][1] = hts["SSIM"].std()

        is_ihz = data_cr_ng[i][j]["Dataset"] == "I-HAZY-NTIRE-2018"
        ihz = data_cr_ng[i][j][is_ihz]
        means[i][j]["mean_mse"][2] = ihz["MSE"].mean()
        means[i][j]["mean_ssim"][2] = ihz["SSIM"].mean()
        means[i][j]["stand_dev_mse"][2] = ihz["MSE"].std()
        means[i][j]["stand_dev_ssim"][2] = ihz["SSIM"].std()

        is_ohz = data_cr_ng[i][j]["Dataset"] == "O-HAZY-NTIRE-2018"
        ohz = data_cr_ng[i][j][is_ohz]
        means[i][j]["mean_mse"][3] = ohz["MSE"].mean()
        means[i][j]["mean_ssim"][3] = ohz["SSIM"].mean()
        means[i][j]["stand_dev_mse"][3] = ohz["MSE"].std()
        means[i][j]["stand_dev_ssim"][3] = ohz["SSIM"].std()

# %%
means_df = pd.DataFrame({})
for i, cr in enumerate(crs):
    for j, ng in enumerate(ngs):
        means_df = means_df.append(pd.DataFrame(means[i][j]), ignore_index=True)

# %%
means_df.head(100)
# Out:
#               Dataset Method  ClipRange  NumGamma  mean_mse  mean_ssim  \
# 0          D-HAZY-MID   AMEF      0.005       3.0  0.068046   0.700802
# 1            HTTS-SYN   AMEF      0.005       3.0  0.023096   0.832928
# 2   I-HAZY-NTIRE-2018   AMEF      0.005       3.0  0.026975   0.627287
# 3   O-HAZY-NTIRE-2018   AMEF      0.005       3.0  0.027831   0.429317
# 4               Total   AMEF      0.005       3.0  0.035719   0.579496
# 5          D-HAZY-MID   AMEF      0.005       4.0  0.056353   0.747037
# 6            HTTS-SYN   AMEF      0.005       4.0  0.018212   0.850753
# 7   I-HAZY-NTIRE-2018   AMEF      0.005       4.0  0.024313   0.629647
# 8   O-HAZY-NTIRE-2018   AMEF      0.005       4.0  0.021394   0.426341
# 9               Total   AMEF      0.005       4.0  0.029355   0.590409
# 10         D-HAZY-MID   AMEF      0.005       5.0  0.050708   0.769350
# 11           HTTS-SYN   AMEF      0.005       5.0  0.018154   0.850651
# 12  I-HAZY-NTIRE-2018   AMEF      0.005       5.0  0.024393   0.627989
# 13  O-HAZY-NTIRE-2018   AMEF      0.005       5.0  0.019680   0.424043
# 14              Total   AMEF      0.005       5.0  0.027456   0.593733
# 15         D-HAZY-MID   AMEF      0.005       6.0  0.049434   0.777664
# 16           HTTS-SYN   AMEF      0.005       6.0  0.020040   0.843634
# 17  I-HAZY-NTIRE-2018   AMEF      0.005       6.0  0.025247   0.625572
# 18  O-HAZY-NTIRE-2018   AMEF      0.005       6.0  0.019571   0.422476
# 19              Total   AMEF      0.005       6.0  0.027551   0.593529
# 20         D-HAZY-MID   AMEF      0.005       7.0  0.045476   0.778517
# 21           HTTS-SYN   AMEF      0.005       7.0  0.023150   0.834968
# 22  I-HAZY-NTIRE-2018   AMEF      0.005       7.0  0.026422   0.623369
# 23  O-HAZY-NTIRE-2018   AMEF      0.005       7.0  0.019954   0.421524
# 24              Total   AMEF      0.005       7.0  0.027482   0.591900
# 25         D-HAZY-MID   AMEF      0.005       8.0  0.043428   0.775449
# 26           HTTS-SYN   AMEF      0.005       8.0  0.026326   0.826456
# 27  I-HAZY-NTIRE-2018   AMEF      0.005       8.0  0.027515   0.621532
# 28  O-HAZY-NTIRE-2018   AMEF      0.005       8.0  0.020423   0.420897
# 29              Total   AMEF      0.005       8.0  0.027839   0.589687
# 30         D-HAZY-MID   AMEF      0.010       3.0  0.065193   0.680124
# 31           HTTS-SYN   AMEF      0.010       3.0  0.026208   0.788771
# 32  I-HAZY-NTIRE-2018   AMEF      0.010       3.0  0.026909   0.611159
# 33  O-HAZY-NTIRE-2018   AMEF      0.010       3.0  0.029450   0.449141
# 34              Total   AMEF      0.010       3.0  0.036056   0.574784
# 35         D-HAZY-MID   AMEF      0.010       4.0  0.056231   0.727684
# 36           HTTS-SYN   AMEF      0.010       4.0  0.021054   0.811439
# 37  I-HAZY-NTIRE-2018   AMEF      0.010       4.0  0.023947   0.616731
# 38  O-HAZY-NTIRE-2018   AMEF      0.010       4.0  0.022721   0.446506
# 39              Total   AMEF      0.010       4.0  0.030043   0.587461
# 40         D-HAZY-MID   AMEF      0.010       5.0  0.051548   0.752125
# 41           HTTS-SYN   AMEF      0.010       5.0  0.020264   0.815714
# 42  I-HAZY-NTIRE-2018   AMEF      0.010       5.0  0.023450   0.616945
# 43  O-HAZY-NTIRE-2018   AMEF      0.010       5.0  0.020500   0.444263
# 44              Total   AMEF      0.010       5.0  0.027910   0.592187
# 45         D-HAZY-MID   AMEF      0.010       6.0  0.050544   0.762261
# 46           HTTS-SYN   AMEF      0.010       6.0  0.021507   0.811837
# 47  I-HAZY-NTIRE-2018   AMEF      0.010       6.0  0.023856   0.615573
# 48  O-HAZY-NTIRE-2018   AMEF      0.010       6.0  0.020022   0.442686
# 49              Total   AMEF      0.010       6.0  0.027724   0.592949
# 50         D-HAZY-MID   AMEF      0.010       7.0  0.046580   0.764363
# 51           HTTS-SYN   AMEF      0.010       7.0  0.024099   0.805299
# 52  I-HAZY-NTIRE-2018   AMEF      0.010       7.0  0.024685   0.614002
# 53  O-HAZY-NTIRE-2018   AMEF      0.010       7.0  0.020166   0.441708
# 54              Total   AMEF      0.010       7.0  0.027411   0.591947
# 55         D-HAZY-MID   AMEF      0.010       8.0  0.044435   0.762160
# 56           HTTS-SYN   AMEF      0.010       8.0  0.026897   0.798209
# 57  I-HAZY-NTIRE-2018   AMEF      0.010       8.0  0.025546   0.612532
# 58  O-HAZY-NTIRE-2018   AMEF      0.010       8.0  0.020490   0.441049
# 59              Total   AMEF      0.010       8.0  0.027587   0.590138
# 60         D-HAZY-MID   AMEF      0.015       3.0  0.062817   0.659617
# 61           HTTS-SYN   AMEF      0.015       3.0  0.029946   0.742158
# 62  I-HAZY-NTIRE-2018   AMEF      0.015       3.0  0.027709   0.582502
# 63  O-HAZY-NTIRE-2018   AMEF      0.015       3.0  0.031306   0.454611
# 64              Total   AMEF      0.015       3.0  0.036891   0.560420
# 65         D-HAZY-MID   AMEF      0.015       4.0  0.055678   0.709062
# 66           HTTS-SYN   AMEF      0.015       4.0  0.024552   0.767896
# 67  I-HAZY-NTIRE-2018   AMEF      0.015       4.0  0.024718   0.590750
# 68  O-HAZY-NTIRE-2018   AMEF      0.015       4.0  0.024500   0.453750
# 69              Total   AMEF      0.015       4.0  0.031205   0.575265
# 70         D-HAZY-MID   AMEF      0.015       5.0  0.051844   0.735587
# 71           HTTS-SYN   AMEF      0.015       5.0  0.023269   0.775257
# 72  I-HAZY-NTIRE-2018   AMEF      0.015       5.0  0.023959   0.592378
# 73  O-HAZY-NTIRE-2018   AMEF      0.015       5.0  0.021998   0.452076
# 74              Total   AMEF      0.015       5.0  0.029017   0.581350
# 75         D-HAZY-MID   AMEF      0.015       6.0  0.051173   0.747470
# 76           HTTS-SYN   AMEF      0.015       6.0  0.024047   0.773716
# 77  I-HAZY-NTIRE-2018   AMEF      0.015       6.0  0.024123   0.591760
# 78  O-HAZY-NTIRE-2018   AMEF      0.015       6.0  0.021290   0.450689
# 79              Total   AMEF      0.015       6.0  0.028696   0.582989
# 80         D-HAZY-MID   AMEF      0.015       7.0  0.047330   0.750817
# 81           HTTS-SYN   AMEF      0.015       7.0  0.026259   0.768772
# 82  I-HAZY-NTIRE-2018   AMEF      0.015       7.0  0.024749   0.590604
# 83  O-HAZY-NTIRE-2018   AMEF      0.015       7.0  0.021277   0.449766
# 84              Total   AMEF      0.015       7.0  0.028251   0.582538
# 85         D-HAZY-MID   AMEF      0.015       8.0  0.045185   0.749507
# 86           HTTS-SYN   AMEF      0.015       8.0  0.028766   0.762768
# 87  I-HAZY-NTIRE-2018   AMEF      0.015       8.0  0.025465   0.589368
# 88  O-HAZY-NTIRE-2018   AMEF      0.015       8.0  0.021502   0.449111
# 89              Total   AMEF      0.015       8.0  0.028319   0.581087
# 90         D-HAZY-MID   AMEF      0.020       3.0  0.061009   0.640267
# 91           HTTS-SYN   AMEF      0.020       3.0  0.033552   0.701262
# 92  I-HAZY-NTIRE-2018   AMEF      0.020       3.0  0.028946   0.551131
# 93  O-HAZY-NTIRE-2018   AMEF      0.020       3.0  0.033122   0.453194
# 94              Total   AMEF      0.020       3.0  0.037940   0.543208
# 95         D-HAZY-MID   AMEF      0.020       4.0  0.055044   0.691578
# 96           HTTS-SYN   AMEF      0.020       4.0  0.027928   0.729089
# 97  I-HAZY-NTIRE-2018   AMEF      0.020       4.0  0.025946   0.561585
# 98  O-HAZY-NTIRE-2018   AMEF      0.020       4.0  0.026314   0.454693
# 99              Total   AMEF      0.020       4.0  0.032480   0.560240
#
#     stand_dev_mse  stand_dev_ssim
# 0        0.048634        0.141584
# 1        0.017304        0.094085
# 2        0.018994        0.137647
# 3        0.016232        0.211338
# 4        0.000000        0.000000
# 5        0.046163        0.135827
# 6        0.013450        0.087840
# 7        0.014373        0.137603
# 8        0.010909        0.215104
# 9        0.000000        0.000000
# 10       0.045627        0.128759
# 11       0.011375        0.079812
# 12       0.012378        0.135600
# 13       0.008611        0.215510
# 14       0.000000        0.000000
# 15       0.046347        0.121485
# 16       0.011054        0.073108
# 17       0.011714        0.133525
# 18       0.008129        0.214899
# 19       0.000000        0.000000
# 20       0.040947        0.113857
# 21       0.011546        0.067801
# 22       0.011555        0.131429
# 23       0.008436        0.214094
# 24       0.000000        0.000000
# 25       0.036499        0.107128
# 26       0.012396        0.063863
# 27       0.011686        0.129808
# 28       0.008969        0.213394
# 29       0.000000        0.000000
# 30       0.047664        0.147506
# 31       0.016628        0.089208
# 32       0.019352        0.124977
# 33       0.015934        0.194895
# 34       0.000000        0.000000
# 35       0.046293        0.141819
# 36       0.013843        0.085625
# 37       0.015332        0.126537
# 38       0.011153        0.200555
# 39       0.000000        0.000000
# 40       0.046262        0.134711
# 41       0.011938        0.079097
# 42       0.013142        0.125412
# 43       0.008593        0.201737
# 44       0.000000        0.000000
# 45       0.047199        0.127187
# 46       0.011248        0.073135
# 47       0.012147        0.123779
# 48       0.007675        0.201450
# 49       0.000000        0.000000
# 50       0.041927        0.119428
# 51       0.011289        0.068197
# 52       0.011720        0.121877
# 53       0.007643        0.200766
# 54       0.000000        0.000000
# 55       0.037498        0.112520
# 56       0.011783        0.064521
# 57       0.011692        0.120340
# 58       0.007983        0.200103
# 59       0.000000        0.000000
# 60       0.046534        0.150424
# 61       0.017152        0.093851
# 62       0.019216        0.112426
# 63       0.015697        0.175804
# 64       0.000000        0.000000
# 65       0.045926        0.145541
# 66       0.014872        0.092468
# 67       0.015783        0.114905
# 68       0.011616        0.182849
# 69       0.000000        0.000000
# 70       0.046346        0.139024
# 71       0.013102        0.087059
# 72       0.013652        0.114231
# 73       0.009234        0.184626
# 74       0.000000        0.000000
# 75       0.047529        0.131735
# 76       0.012242        0.081529
# 77       0.012531        0.112789
# 78       0.008215        0.184598
# 79       0.000000        0.000000
# 80       0.042456        0.124119
# 81       0.012011        0.076715
# 82       0.011940        0.110914
# 83       0.007985        0.184017
# 84       0.000000        0.000000
# 85       0.038117        0.117177
# 86       0.012244        0.073061
# 87       0.011788        0.109350
# 88       0.008148        0.183388
# 89       0.000000        0.000000
# 90       0.045421        0.150989
# 91       0.018046        0.098929
# 92       0.019002        0.102157
# 93       0.015586        0.158594
# 94       0.000000        0.000000
# 95       0.045332        0.146958
# 96       0.016042        0.099846
# 97       0.016001        0.105367
# 98       0.012104        0.166457
# 99       0.000000        0.000000

# %%
is_total = means_df["Dataset"] == "Total"
means_total = means_df[is_total]

# %%
Pallette = ["#FFFFFF", "#00FF00", "#000000"]
Outline = ["#000000", "#FFFFFF"]

(ggplot(means_df, aes(x="NumGamma", y="ClipRange", fill="mean_mse", color='mean_mse'))
 + geom_tile()
 + scale_fill_gradientn(Pallette,)
 + scale_color_gradientn(Outline,)
 + facet_grid('. ~ Dataset')
 + theme(axis_text_x=element_text(rotation=45, hjust=1))
 + theme(figure_size=(9, 4))  # here you define the plot size
 + ggtitle("Mean MSE by Clip Range and Number of Gamma Levels (Lower is better)")
 + labs(x="Dataset", y="Mean MSE")
)
# Out:
# <ggplot: (20009057)>

# %%
Pallette = ["#FFFFFF", "#00FF00", "#000000"]
Outline = ["#000000", "#FFFFFF"]

(ggplot(means_df, aes(x="NumGamma", y="ClipRange", fill="stand_dev_mse", color='stand_dev_mse'))
 + geom_tile()
 + scale_fill_gradientn(Pallette,)
 + scale_color_gradientn(Outline,)
 + facet_grid('. ~ Dataset')
 + theme(axis_text_x=element_text(rotation=45, hjust=1))
 + theme(figure_size=(9, 4))  # here you define the plot size
 + ggtitle("Mean MSE by Clip Range and Number of Gamma Levels (Lower is better)")
 + labs(x="Dataset", y="Mean MSE")
)
# Out:
# <ggplot: (21503464)>

# %%
Pallette = ["#FFFFFF", "#00FF00", "#000000"]
Outline = ["#000000", "#FFFFFF"]

(ggplot(means_total, aes(x="NumGamma", y="ClipRange", fill="mean_mse", color='mean_mse'))
 + geom_tile()
 + facet_grid('. ~ Dataset')
 + scale_fill_gradientn(Pallette,)
 + scale_color_gradientn(Outline,)
 + theme(axis_text_x=element_text(rotation=45, hjust=1))
 + theme(figure_size=(9, 4))  # here you define the plot size
 + ggtitle("Mean MSE by Clip Range and Number of Gamma Levels  (Lower is better)")
 + labs(x="Dataset", y="Mean MSE")
)
# Out:
# <ggplot: (21241691)>

# %%
Pallette = ["#000000", "#FF00FF", "#FFFFFF"]
Outline = ["#FFFFFF", "#000000"]

(ggplot(means_df, aes(x="NumGamma", y="ClipRange", fill="mean_ssim", color="mean_ssim"))
 + geom_tile()
 + scale_fill_gradientn(Pallette,)
 + scale_color_gradientn(Outline,)
 + facet_grid('. ~ Dataset')
 + theme(axis_text_x=element_text(rotation=45, hjust=1))
 + theme(figure_size=(9, 4))  # here you define the plot size
 + ggtitle("Mean SSIM by Clip Range and Number of Gamma Levels (Higher is better)")
 + labs(x="Number of Gamma Levels", y="Clip Range")
)
# Out:
# <ggplot: (-2141629204)>

# %%
Pallette = ["#000000", "#FF00FF", "#FFFFFF"]
Outline = ["#FFFFFF", "#000000"]

(ggplot(means_df, aes(x="NumGamma", y="ClipRange", fill="stand_dev_ssim", color="stand_dev_ssim"))
 + geom_tile()
 + scale_fill_gradientn(Pallette,)
 + scale_color_gradientn(Outline,)
 + facet_grid('. ~ Dataset')
 + theme(axis_text_x=element_text(rotation=45, hjust=1))
 + theme(figure_size=(9, 4))  # here you define the plot size
 + ggtitle("Mean SSIM by Clip Range and Number of Gamma Levels (Higher is better)")
 + labs(x="Number of Gamma Levels", y="Clip Range")
)
# Out:
# <ggplot: (21454324)>

# %%
(ggplot(means_total, aes(x="NumGamma", y="ClipRange", fill="mean_ssim", color="mean_ssim"))
 + geom_tile()
 + scale_fill_gradientn(Pallette,)
 + scale_color_gradientn(Outline,)
 + facet_grid('. ~ Dataset')
 + theme(axis_text_x=element_text(rotation=45, hjust=1))
 + theme(figure_size=(9, 4))  # here you define the plot size
 + ggtitle("Mean SSIM by Clip Range and Number of Gamma Levels (Higher is better)")
 + labs(x="Number of Gamma Levels", y="Clip Range")
)
# Out:
# <ggplot: (21257557)>

# %%
(ggplot(means_hazy, aes(x="Dataset", y="mean_mse"))
 + geom_col(stat='identity', position='dodge')
 + theme(axis_text_x=element_text(rotation=45, hjust=1))
 + theme(figure_size=(9, 4))  # here you define the plot size
 + ggtitle("Mean MSE Hazy (Lower is better)")
 + labs(x="Dataset", y="MSE")
)
# Out:
# <ggplot: (21456622)>

# %%
(ggplot(means_hazy, aes(x="Dataset", y="mean_ssim"))
 + geom_col(stat='identity', position='dodge')
 + theme(axis_text_x=element_text(rotation=45, hjust=1))
 + theme(figure_size=(9, 4))  # here you define the plot size
 + ggtitle("Mean SSIM Hazy (Higher is better)")
 + labs(x="Dataset", y="SSIM")
)
# Out:
# <ggplot: (-2125846045)>

# %%
data.head()
# Out:
#       Dataset        Filename  Size(Pixels) Method       MSE      SSIM  \
# 0  D-HAZY-MID  Adirondack_im0      17176320   HAZY  0.093500  0.686573
# 1  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.045760  0.768561
# 2  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.033644  0.816057
# 3  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.026954  0.846020
# 4  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.023657  0.862817
#
#    ClipRange  NumGamma      Time
# 0      0.000       0.0       NaN
# 1      0.005       3.0  7.339993
# 2      0.005       4.0  8.067115
# 3      0.005       5.0  8.692747
# 4      0.005       6.0  9.462002

# %%
data_hazy.head()
# Out:
#         Dataset        Filename  Size(Pixels) Method       MSE      SSIM  \
# 0    D-HAZY-MID  Adirondack_im0      17176320   HAZY  0.093500  0.686573
# 37   D-HAZY-MID    Backpack_im0      17781120   HAZY  0.043494  0.747612
# 74   D-HAZY-MID    Bicycle1_im0      17999712   HAZY  0.020871  0.894461
# 111  D-HAZY-MID       Cable_im0      16641792   HAZY  0.291404  0.529118
# 148  D-HAZY-MID  Classroom1_im0      17280000   HAZY  0.201291  0.457680
#
#      ClipRange  NumGamma  Time
# 0          0.0       0.0   NaN
# 37         0.0       0.0   NaN
# 74         0.0       0.0   NaN
# 111        0.0       0.0   NaN
# 148        0.0       0.0   NaN

# %%
data["rootSize"] = data['Size(Pixels)'] ** (1/2)

# %%
isDeHazed = data['Method'] == "AMEF"
data_dehazed = data[isDeHazed]

# %%
(ggplot(data_dehazed, aes(x="Size(Pixels)", y="Time", color="NumGamma"))
+ geom_point()
+ ggtitle("RunTime (Seconds) vs number of Gamma Levels"))
# Out:
# <ggplot: (21399438)>

# %%
(ggplot(data_hazy, aes(x="Dataset", y="MSE"))
+ geom_boxplot()
+ ylim(0,0.3)
+ theme(axis_text_x=element_text(rotation=45, hjust=1))
+ ggtitle("Distribution of MSE by Dataset (HAZY)"))
# Out:
# <ggplot: (-2125825074)>

# %%
(ggplot(data_hazy, aes(x="Dataset", y="SSIM", ymax=1, ymin=0))
+ geom_boxplot()
+ ylim(0,1)
+ theme(axis_text_x=element_text(rotation=45, hjust=1))
+ ggtitle("Distribution of SSIM by Dataset (HAZY)"))
# Out:
# <ggplot: (-2125822420)>

# %%
for i, cr in enumerate(crs):
    for j, ng in enumerate(ngs):
        ssimTitle = 'Distribution of SSIM by Dataset (CR = {c}, NumGamma = {g})'.format(c = cr, g = ng)
        mseTitle = 'Distribution of MSE by Dataset (CR = {c}, NumGamma = {g})'.format(c = cr, g = ng)
        ssimFN = './Figures/ssim_{c}_{g}.png'.format(c = cr, g = ng)
        mseFN = './Figures/mse_{c}_{g}.png'.format(c = cr, g = ng)
        ssim = (ggplot(data_cr_ng[i][j], aes(x="Dataset", y="SSIM"))
            + geom_boxplot()
            + ylim(0,1)
            + theme(axis_text_x=element_text(rotation=45, hjust=1))
            + ggtitle(ssimTitle))
        ssim.save(filename=ssimFN)
        mse = (ggplot(data_cr_ng[i][j], aes(x="Dataset", y="MSE"))
            + geom_boxplot()
            + ylim(0,0.3)
            + theme(axis_text_x=element_text(rotation=45, hjust=1))
            + ggtitle(mseTitle))
        mse.save(filename=mseFN)

# %%
means_df.head()
# Out:
#              Dataset Method  ClipRange  NumGamma  mean_mse  mean_ssim  \
# 0         D-HAZY-MID   AMEF      0.005       3.0  0.068046   0.700802
# 1           HTTS-SYN   AMEF      0.005       3.0  0.023096   0.832928
# 2  I-HAZY-NTIRE-2018   AMEF      0.005       3.0  0.026975   0.627287
# 3  O-HAZY-NTIRE-2018   AMEF      0.005       3.0  0.027831   0.429317
# 4              Total   AMEF      0.005       3.0  0.035719   0.579496
#
#    stand_dev_mse  stand_dev_ssim
# 0       0.048634        0.141584
# 1       0.017304        0.094085
# 2       0.018994        0.137647
# 3       0.016232        0.211338
# 4       0.000000        0.000000

# %%
hz_DHZ=pd.read_csv("../dataDHZ.csv")
hz_DHZ=pd.concat([hz_DHZ]*37)
hz_DHZ=hz_DHZ.rename(columns={"0": "name", "1": "mean", "2": "std"})
hz_DHZ=hz_DHZ.sort_values(by=['name'])

hz_HTS=pd.read_csv("../dataHTS.csv")
hz_HTS=pd.concat([hz_HTS]*37)
hz_HTS=hz_HTS.rename(columns={"0": "name", "1": "mean", "2": "std"})
hz_HTS=hz_HTS.sort_values(by=['name'])

hz_IHZ=pd.read_csv("../dataIHZ.csv")
hz_IHZ=pd.concat([hz_IHZ]*37)
hz_IHZ=hz_IHZ.rename(columns={"0": "name", "1": "mean", "2": "std"})
hz_IHZ=hz_IHZ.sort_values(by=['name'])

hz_OHZ=pd.read_csv("../dataOHZ.csv")
hz_OHZ=pd.concat([hz_OHZ]*37)
hz_OHZ=hz_OHZ.rename(columns={"0": "name", "1": "mean", "2": "std"})
hz_OHZ=hz_OHZ.sort_values(by=['name'])

# %%
hz_DHZ.head()
# Out:
#                   name    mean     std
# 0  Adirondack_Hazy.bmp  0.9868  0.0888
# 0  Adirondack_Hazy.bmp  0.9868  0.0888
# 0  Adirondack_Hazy.bmp  0.9868  0.0888
# 0  Adirondack_Hazy.bmp  0.9868  0.0888
# 0  Adirondack_Hazy.bmp  0.9868  0.0888

# %%
hz = pd.concat([hz_DHZ,hz_HTS,hz_IHZ,hz_OHZ]).reset_index()

# %%
data = data.reset_index()

# %%
hz.head()
# Out:
#    index                 name    mean     std
# 0      0  Adirondack_Hazy.bmp  0.9868  0.0888
# 1      0  Adirondack_Hazy.bmp  0.9868  0.0888
# 2      0  Adirondack_Hazy.bmp  0.9868  0.0888
# 3      0  Adirondack_Hazy.bmp  0.9868  0.0888
# 4      0  Adirondack_Hazy.bmp  0.9868  0.0888

# %%
hz.shape
# Out:
# (3996, 3)

# %%
data['Haziness'] = hz['mean']

# %%
isDeHazed = data['Method'] == "AMEF"
data_dehazed = data[isDeHazed]

# %%
data_dehazed.head(40)
# Out:
#     index     Dataset        Filename  Size(Pixels) Method       MSE  \
# 1       1  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.045760
# 2       2  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.033644
# 3       3  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.026954
# 4       4  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.023657
# 5       5  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.020338
# 6       6  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.018654
# 7       7  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.043530
# 8       8  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.034150
# 9       9  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.028149
# 10     10  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.024838
# 11     11  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.021232
# 12     12  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.019254
# 13     13  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.040887
# 14     14  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.033655
# 15     15  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.028569
# 16     16  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.025527
# 17     17  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.021873
# 18     18  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.019755
# 19     19  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.038459
# 20     20  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.032708
# 21     21  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.028489
# 22     22  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.025841
# 23     23  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.022303
# 24     24  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.020167
# 25     25  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.036352
# 26     26  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.031601
# 27     27  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.028108
# 28     28  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.025872
# 29     29  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.022530
# 30     30  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.020445
# 31     31  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.034603
# 32     32  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.030510
# 33     33  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.027577
# 34     34  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.025714
# 35     35  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.022604
# 36     36  D-HAZY-MID  Adirondack_im0      17176320   AMEF  0.020615
# 38     38  D-HAZY-MID    Backpack_im0      17781120   AMEF  0.024045
# 39     39  D-HAZY-MID    Backpack_im0      17781120   AMEF  0.018466
# 40     40  D-HAZY-MID    Backpack_im0      17781120   AMEF  0.017549
# 41     41  D-HAZY-MID    Backpack_im0      17781120   AMEF  0.019385
#
#         SSIM  ClipRange  NumGamma       Time     rootSize  \
# 1   0.768561      0.005       3.0   7.339993  4144.432410
# 2   0.816057      0.005       4.0   8.067115  4144.432410
# 3   0.846020      0.005       5.0   8.692747  4144.432410
# 4   0.862817      0.005       6.0   9.462002  4144.432410
# 5   0.871445      0.005       7.0  11.543515  4144.432410
# 6   0.874759      0.005       8.0  13.631208  4144.432410
# 7   0.762547      0.010       3.0   7.329089  4144.432410
# 8   0.803295      0.010       4.0   8.004766  4144.432410
# 9   0.831613      0.010       5.0   8.525540  4144.432410
# 10  0.849034      0.010       6.0   9.197295  4144.432410
# 11  0.858920      0.010       7.0  11.458892  4144.432410
# 12  0.863469      0.010       8.0  13.770080  4144.432410
# 13  0.755547      0.015       3.0   7.169138  4144.432410
# 14  0.792725      0.015       4.0   8.088931  4144.432410
# 15  0.819493      0.015       5.0   8.618524  4144.432410
# 16  0.836909      0.015       6.0   9.264420  4144.432410
# 17  0.847451      0.015       7.0  11.428887  4144.432410
# 18  0.852778      0.015       8.0  13.892082  4144.432410
# 19  0.746053      0.020       3.0   7.287341  4144.432410
# 20  0.781790      0.020       4.0   7.930836  4144.432410
# 21  0.807523      0.020       5.0   8.601726  4144.432410
# 22  0.824744      0.020       6.0   9.276107  4144.432410
# 23  0.835597      0.020       7.0  11.680143  4144.432410
# 24  0.841408      0.020       8.0  13.773301  4144.432410
# 25  0.734929      0.025       3.0   7.339741  4144.432410
# 26  0.770206      0.025       4.0   7.850110  4144.432410
# 27  0.795428      0.025       5.0   8.658081  4144.432410
# 28  0.812593      0.025       6.0   9.220521  4144.432410
# 29  0.823738      0.025       7.0  11.497470  4144.432410
# 30  0.829986      0.025       8.0  13.644148  4144.432410
# 31  0.722732      0.030       3.0   7.240103  4144.432410
# 32  0.758126      0.030       4.0   7.999164  4144.432410
# 33  0.783345      0.030       5.0   8.635038  4144.432410
# 34  0.800743      0.030       6.0   9.319964  4144.432410
# 35  0.812323      0.030       7.0  11.631319  4144.432410
# 36  0.819103      0.030       8.0  13.651576  4144.432410
# 38  0.822529      0.005       3.0   7.611367  4216.766534
# 39  0.870033      0.005       4.0   8.261947  4216.766534
# 40  0.881735      0.005       5.0   8.948114  4216.766534
# 41  0.876344      0.005       6.0   9.672282  4216.766534
#
#                    name  Haziness
# 1   Adirondack_Hazy.bmp    0.9868
# 2   Adirondack_Hazy.bmp    0.9868
# 3   Adirondack_Hazy.bmp    0.9868
# 4   Adirondack_Hazy.bmp    0.9868
# 5   Adirondack_Hazy.bmp    0.9868
# 6   Adirondack_Hazy.bmp    0.9868
# 7   Adirondack_Hazy.bmp    0.9868
# 8   Adirondack_Hazy.bmp    0.9868
# 9   Adirondack_Hazy.bmp    0.9868
# 10  Adirondack_Hazy.bmp    0.9868
# 11  Adirondack_Hazy.bmp    0.9868
# 12  Adirondack_Hazy.bmp    0.9868
# 13  Adirondack_Hazy.bmp    0.9868
# 14  Adirondack_Hazy.bmp    0.9868
# 15  Adirondack_Hazy.bmp    0.9868
# 16  Adirondack_Hazy.bmp    0.9868
# 17  Adirondack_Hazy.bmp    0.9868
# 18  Adirondack_Hazy.bmp    0.9868
# 19  Adirondack_Hazy.bmp    0.9868
# 20  Adirondack_Hazy.bmp    0.9868
# 21  Adirondack_Hazy.bmp    0.9868
# 22  Adirondack_Hazy.bmp    0.9868
# 23  Adirondack_Hazy.bmp    0.9868
# 24  Adirondack_Hazy.bmp    0.9868
# 25  Adirondack_Hazy.bmp    0.9868
# 26  Adirondack_Hazy.bmp    0.9868
# 27  Adirondack_Hazy.bmp    0.9868
# 28  Adirondack_Hazy.bmp    0.9868
# 29  Adirondack_Hazy.bmp    0.9868
# 30  Adirondack_Hazy.bmp    0.9868
# 31  Adirondack_Hazy.bmp    0.9868
# 32  Adirondack_Hazy.bmp    0.9868
# 33  Adirondack_Hazy.bmp    0.9868
# 34  Adirondack_Hazy.bmp    0.9868
# 35  Adirondack_Hazy.bmp    0.9868
# 36  Adirondack_Hazy.bmp    0.9868
# 38    Backpack_Hazy.bmp    0.9788
# 39    Backpack_Hazy.bmp    0.9788
# 40    Backpack_Hazy.bmp    0.9788
# 41    Backpack_Hazy.bmp    0.9788

# %%
(ggplot(data_dehazed, aes(x="Haziness", y="SSIM", color="Dataset"))
+ geom_point()
+ facet_grid("ClipRange ~ NumGamma")
+ ggtitle("RunTime (Seconds) vs number of Gamma Levels"))
# Out:
# <ggplot: (28266177)>

# %%
hzMSE = pd.DataFrame(columns = data_hazy.columns)
hzSSIM = pd.DataFrame(columns = data_hazy.columns)

nameCurr = ""
namePrev = ""
minMSE = 1
maxSSIM = 0
started = False
bestMSE = None
bestSSIM = None
for row in data_dehazed.iterrows():
    nameCurr = row[1]["Filename"]
    
    if nameCurr != namePrev and started:
        hzMSE = hzMSE.append(data_dehazed.iloc[bestMSE], ignore_index=True)
#         hzSSIM = pd.concat([hzSSIM,data_dehazed.iloc[bestSSIM]])
    
        bestMSE = None
        bestSSIM = None
        minMSE = 1
        maxSSIM = 0
        
    started = True
        
    if row[1]['MSE'] < minMSE:
        bestMSE = row[1]["index"]
        minMSE = row[1]['MSE']
    
    if row[1]['SSIM'] > maxSSIM:
        bestSSIM = row[1]["index"]
        maxSSIM = row[1]['SSIM']
        
    namePrev = nameCurr
# Out:
# index                             7
# Dataset                  D-HAZY-MID
# Filename             Adirondack_im0
# Size(Pixels)               17176320
# Method                         AMEF
# MSE                         0.04353
# SSIM                       0.762547
# ClipRange                      0.01
# NumGamma                          3
# Time                        7.32909
# rootSize                    4144.43
# name            Adirondack_Hazy.bmp
# Haziness                     0.9868
# Name: 7, dtype: object
# index                          42
# Dataset                D-HAZY-MID
# Filename             Backpack_im0
# Size(Pixels)             17781120
# Method                       AMEF
# MSE                      0.022523
# SSIM                     0.863435
# ClipRange                   0.005
# NumGamma                        7
# Time                      11.7746
# rootSize                  4216.77
# name            Backpack_Hazy.bmp
# Haziness                   0.9788
# Name: 42, dtype: object
# index                          80
# Dataset                D-HAZY-MID
# Filename             Bicycle1_im0
# Size(Pixels)             17999712
# Method                       AMEF
# MSE                      0.018449
# SSIM                     0.875464
# ClipRange                   0.005
# NumGamma                        8
# Time                      14.1942
# rootSize                  4242.61
# name            Bicycle1_Hazy.bmp
# Haziness                     0.97
# Name: 80, dtype: object
# index                      146
# Dataset             D-HAZY-MID
# Filename             Cable_im0
# Size(Pixels)          16641792
# Method                    AMEF
# MSE                   0.171282
# SSIM                  0.572623
# ClipRange                 0.03
# NumGamma                     7
# Time                   11.0386
# rootSize               4079.44
# name            Cable_Hazy.bmp
# Haziness                0.9785
# Name: 146, dtype: object
# index                           159
# Dataset                  D-HAZY-MID
# Filename             Classroom1_im0
# Size(Pixels)               17280000
# Method                         AMEF
# MSE                        0.039906
# SSIM                        0.70714
# ClipRange                      0.01
# NumGamma                          7
# Time                        11.5192
# rootSize                    4156.92
# name            Classroom1_Hazy.bmp
# Haziness                      0.985
# Name: 159, dtype: object
# index                      197
# Dataset             D-HAZY-MID
# Filename             Couch_im0
# Size(Pixels)          13744800
# Method                    AMEF
# MSE                   0.039851
# SSIM                  0.666438
# ClipRange                 0.01
# NumGamma                     8
# Time                    10.547
# rootSize                3707.4
# name            Couch_Hazy.bmp
# Haziness                 0.985
# Name: 197, dtype: object
# index                          266
# Dataset                 D-HAZY-MID
# Filename             Jadeplant_im0
# Size(Pixels)              15697248
# Method                        AMEF
# MSE                       0.152286
# SSIM                      0.551027
# ClipRange                     0.01
# NumGamma                         3
# Time                       6.56753
# rootSize                   3961.98
# name            Jadeplant_Hazy.bmp
# Haziness                     0.981
# Name: 266, dtype: object
# index                          273
# Dataset                 D-HAZY-MID
# Filename             Jadeplant_im0
# Size(Pixels)              15697248
# Method                        AMEF
# MSE                        0.14733
# SSIM                      0.577643
# ClipRange                    0.015
# NumGamma                         4
# Time                       7.24977
# rootSize                   3961.98
# name            Jadeplant_Hazy.bmp
# Haziness                     0.981
# Name: 273, dtype: object
# index                           337
# Dataset                  D-HAZY-MID
# Filename             Motorcycle_im0
# Size(Pixels)               17784000
# Method                         AMEF
# MSE                        0.041718
# SSIM                       0.770692
# ClipRange                     0.005
# NumGamma                          6
# Time                        11.2919
# rootSize                    4217.11
# name            Motorcycle_Hazy.bmp
# Haziness                     0.9892
# Name: 337, dtype: object
# index                      380
# Dataset             D-HAZY-MID
# Filename             Piano_im0
# Size(Pixels)          16243200
# Method                    AMEF
# MSE                   0.037613
# SSIM                  0.667138
# ClipRange                 0.01
# NumGamma                     6
# Time                   8.60275
# rootSize               4030.29
# name            Piano_Hazy.bmp
# Haziness                 0.987
# Name: 380, dtype: object
# index                      387
# Dataset             D-HAZY-MID
# Filename             Piano_im0
# Size(Pixels)          16243200
# Method                    AMEF
# MSE                   0.037835
# SSIM                  0.635971
# ClipRange                0.015
# NumGamma                     7
# Time                   10.5742
# rootSize               4030.29
# name            Piano_Hazy.bmp
# Haziness                 0.987
# Name: 387, dtype: object
# index                      425
# Dataset             D-HAZY-MID
# Filename             Pipes_im0
# Size(Pixels)          17085120
# Method                    AMEF
# MSE                    0.06478
# SSIM                  0.653224
# ClipRange                0.015
# NumGamma                     8
# Time                    13.455
# rootSize               4133.42
# name            Pipes_Hazy.bmp
# Haziness                0.9828
# Name: 425, dtype: object
# index                         463
# Dataset                D-HAZY-MID
# Filename             Playroom_im0
# Size(Pixels)             16027200
# Method                       AMEF
# MSE                      0.056914
# SSIM                     0.567681
# ClipRange                    0.02
# NumGamma                        3
# Time                      6.64506
# rootSize                   4003.4
# name            Playroom_Hazy.bmp
# Haziness                   0.9855
# Name: 463, dtype: object
# index                          501
# Dataset                 D-HAZY-MID
# Filename             Playtable_im0
# Size(Pixels)              15101856
# Method                        AMEF
# MSE                        0.02972
# SSIM                      0.670138
# ClipRange                     0.02
# NumGamma                         4
# Time                       6.83362
# rootSize                   3886.11
# name            Playtable_Hazy.bmp
# Haziness                    0.9862
# Name: 501, dtype: object
# index                        543
# Dataset               D-HAZY-MID
# Filename             Recycle_im0
# Size(Pixels)            16531008
# Method                      AMEF
# MSE                     0.019187
# SSIM                    0.721186
# ClipRange                  0.025
# NumGamma                       3
# Time                     6.89534
# rootSize                 4065.83
# name            Recycle_Hazy.bmp
# Haziness                  0.9808
# Name: 543, dtype: object
# index                        581
# Dataset               D-HAZY-MID
# Filename             Shelves_im0
# Size(Pixels)            17712000
# Method                      AMEF
# MSE                     0.014271
# SSIM                    0.765958
# ClipRange                  0.025
# NumGamma                       4
# Time                     8.07249
# rootSize                 4208.56
# name            Shelves_Hazy.bmp
# Haziness                   0.985
# Name: 581, dtype: object
# index                       641
# Dataset              D-HAZY-MID
# Filename             Sticks_im0
# Size(Pixels)           17252736
# Method                     AMEF
# MSE                    0.022646
# SSIM                   0.912973
# ClipRange                  0.01
# NumGamma                      8
# Time                    13.5626
# rootSize                4153.64
# name            Sticks_Hazy.bmp
# Haziness                 0.9615
# Name: 641, dtype: object
# index                       650
# Dataset              D-HAZY-MID
# Filename             Sticks_im0
# Size(Pixels)           17252736
# Method                     AMEF
# MSE                    0.008666
# SSIM                   0.923088
# ClipRange                  0.02
# NumGamma                      5
# Time                    8.60659
# rootSize                4153.64
# name            Sticks_Hazy.bmp
# Haziness                 0.9615
# Name: 650, dtype: object
# index                       717
# Dataset              D-HAZY-MID
# Filename             Sword1_im0
# Size(Pixels)           17646720
# Method                     AMEF
# MSE                    0.032446
# SSIM                   0.783811
# ClipRange                 0.015
# NumGamma                      4
# Time                    8.21064
# rootSize                 4200.8
# name            Sword1_Hazy.bmp
# Haziness                 0.9708
# Name: 717, dtype: object
# index                       727
# Dataset              D-HAZY-MID
# Filename             Sword1_im0
# Size(Pixels)           17646720
# Method                     AMEF
# MSE                    0.032326
# SSIM                   0.854631
# ClipRange                  0.02
# NumGamma                      8
# Time                    14.1076
# rootSize                 4200.8
# name            Sword1_Hazy.bmp
# Haziness                 0.9708
# Name: 727, dtype: object
# index                         787
# Dataset                D-HAZY-MID
# Filename             Umbrella_im0
# Size(Pixels)             17902080
# Method                       AMEF
# MSE                      0.029964
# SSIM                     0.849573
# ClipRange                    0.01
# NumGamma                        6
# Time                      9.44794
# rootSize                  4231.08
# name            Umbrella_Hazy.bmp
# Haziness                    0.979
# Name: 787, dtype: object
# index                         802
# Dataset                D-HAZY-MID
# Filename             Umbrella_im0
# Size(Pixels)             17902080
# Method                       AMEF
# MSE                      0.035425
# SSIM                      0.71621
# ClipRange                   0.025
# NumGamma                        3
# Time                      7.43748
# rootSize                  4231.08
# name            Umbrella_Hazy.bmp
# Haziness                    0.979
# Name: 802, dtype: object
# index                858
# Dataset         HTTS-SYN
# Filename            0586
# Size(Pixels)      681450
# Method              AMEF
# MSE             0.014464
# SSIM            0.854648
# ClipRange           0.01
# NumGamma               3
# Time            0.410789
# rootSize           825.5
# name            0586.jpg
# Haziness          0.9852
# Name: 858, dtype: object
# index                876
# Dataset         HTTS-SYN
# Filename            0586
# Size(Pixels)      681450
# Method              AMEF
# MSE             0.025318
# SSIM            0.736639
# ClipRange          0.025
# NumGamma               3
# Time              0.4008
# rootSize           825.5
# name            0586.jpg
# Haziness          0.9852
# Name: 876, dtype: object
# index                915
# Dataset         HTTS-SYN
# Filename            1352
# Size(Pixels)     1214400
# Method              AMEF
# MSE             0.021021
# SSIM            0.722027
# ClipRange          0.025
# NumGamma               5
# Time            0.694376
# rootSize            1102
# name            1352.jpg
# Haziness          0.9785
# Name: 915, dtype: object
# index                954
# Dataset         HTTS-SYN
# Filename            1381
# Size(Pixels)      681450
# Method              AMEF
# MSE             0.064742
# SSIM            0.561162
# ClipRange          0.025
# NumGamma               7
# Time            0.568179
# rootSize           825.5
# name            1381.jpg
# Haziness          0.9732
# Name: 954, dtype: object
# index                994
# Dataset         HTTS-SYN
# Filename            3146
# Size(Pixels)      509850
# Method              AMEF
# MSE             0.044246
# SSIM            0.551169
# ClipRange           0.03
# NumGamma               4
# Time            0.366377
# rootSize         714.038
# name            3146.jpg
# Haziness          0.9738
# Name: 994, dtype: object
# index               1031
# Dataset         HTTS-SYN
# Filename            4184
# Size(Pixels)      772200
# Method              AMEF
# MSE              0.03386
# SSIM            0.715164
# ClipRange           0.03
# NumGamma               4
# Time            0.467121
# rootSize         878.749
# name            4184.jpg
# Haziness          0.9742
# Name: 1031, dtype: object
# index               1070
# Dataset         HTTS-SYN
# Filename            4561
# Size(Pixels)      509850
# Method              AMEF
# MSE             0.020545
# SSIM            0.664678
# ClipRange           0.03
# NumGamma               6
# Time            0.404181
# rootSize         714.038
# name            4561.jpg
# Haziness          0.9668
# Name: 1070, dtype: object
# index               1107
# Dataset         HTTS-SYN
# Filename            5576
# Size(Pixels)      509850
# Method              AMEF
# MSE             0.042659
# SSIM            0.576081
# ClipRange           0.03
# NumGamma               6
# Time            0.399511
# rootSize         714.038
# name            5576.jpg
# Haziness          0.9758
# Name: 1107, dtype: object
# index               1143
# Dataset         HTTS-SYN
# Filename            5920
# Size(Pixels)      681450
# Method              AMEF
# MSE             0.033904
# SSIM            0.707192
# ClipRange           0.03
# NumGamma               5
# Time            0.462613
# rootSize           825.5
# name            5920.jpg
# Haziness          0.9782
# Name: 1143, dtype: object
# index               1180
# Dataset         HTTS-SYN
# Filename            7471
# Size(Pixels)      567600
# Method              AMEF
# MSE             0.014354
# SSIM            0.842187
# ClipRange           0.03
# NumGamma               5
# Time            0.405294
# rootSize         753.392
# name            7471.jpg
# Haziness           0.975
# Name: 1180, dtype: object
# index               1219
# Dataset         HTTS-SYN
# Filename            8180
# Size(Pixels)      570696
# Method              AMEF
# MSE             0.015553
# SSIM            0.825892
# ClipRange           0.03
# NumGamma               7
# Time            0.527099
# rootSize         755.444
# name            8180.jpg
# Haziness          0.9822
# Name: 1219, dtype: object
# index                         1270
# Dataset          I-HAZY-NTIRE-2018
# Filename                 02_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.033833
# SSIM                       0.81707
# ClipRange                     0.01
# NumGamma                         8
# Time                       30.6454
# rootSize                   6291.25
# name            02_indoor_hazy.jpg
# Haziness                      0.83
# Name: 1270, dtype: object
# index                         1325
# Dataset          I-HAZY-NTIRE-2018
# Filename                 03_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.026762
# SSIM                      0.441808
# ClipRange                    0.025
# NumGamma                         8
# Time                       30.8906
# rootSize                   6291.25
# name            03_indoor_hazy.jpg
# Haziness                     0.952
# Name: 1325, dtype: object
# index                         1344
# Dataset          I-HAZY-NTIRE-2018
# Filename                 04_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.034238
# SSIM                      0.430709
# ClipRange                     0.01
# NumGamma                         8
# Time                       31.1744
# rootSize                   6291.25
# name            04_indoor_hazy.jpg
# Haziness                      0.98
# Name: 1344, dtype: object
# index                         1376
# Dataset          I-HAZY-NTIRE-2018
# Filename                 05_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.012913
# SSIM                      0.703258
# ClipRange                     0.01
# NumGamma                         3
# Time                       17.1453
# rootSize                   6291.25
# name            05_indoor_hazy.jpg
# Haziness                      0.87
# Name: 1376, dtype: object
# index                         1415
# Dataset          I-HAZY-NTIRE-2018
# Filename                 06_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.016447
# SSIM                      0.694687
# ClipRange                     0.01
# NumGamma                         5
# Time                       20.3642
# rootSize                   6291.25
# name            06_indoor_hazy.jpg
# Haziness                     0.978
# Name: 1415, dtype: object
# index                         1464
# Dataset          I-HAZY-NTIRE-2018
# Filename                 07_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.026469
# SSIM                      0.442304
# ClipRange                     0.02
# NumGamma                         5
# Time                       20.0824
# rootSize                   6291.25
# name            07_indoor_hazy.jpg
# Haziness                     0.998
# Name: 1464, dtype: object
# index                         1504
# Dataset          I-HAZY-NTIRE-2018
# Filename                 08_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.026338
# SSIM                      0.560398
# ClipRange                     0.02
# NumGamma                         8
# Time                       30.7283
# rootSize                   6291.25
# name            08_indoor_hazy.jpg
# Haziness                     0.933
# Name: 1504, dtype: object
# index                         1556
# Dataset          I-HAZY-NTIRE-2018
# Filename                 10_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.015015
# SSIM                       0.67685
# ClipRange                    0.005
# NumGamma                         4
# Time                       18.4559
# rootSize                   6291.25
# name            10_indoor_hazy.jpg
# Haziness                      0.95
# Name: 1556, dtype: object
# index                         1569
# Dataset          I-HAZY-NTIRE-2018
# Filename                 10_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.012993
# SSIM                       0.62637
# ClipRange                    0.015
# NumGamma                         5
# Time                       20.0734
# rootSize                   6291.25
# name            10_indoor_hazy.jpg
# Haziness                      0.95
# Name: 1569, dtype: object
# index                         1605
# Dataset          I-HAZY-NTIRE-2018
# Filename                 11_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.054431
# SSIM                      0.356477
# ClipRange                    0.015
# NumGamma                         4
# Time                       18.6144
# rootSize                   6291.25
# name            11_indoor_hazy.jpg
# Haziness                     0.893
# Name: 1605, dtype: object
# index                         1642
# Dataset          I-HAZY-NTIRE-2018
# Filename                 12_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.021992
# SSIM                      0.616253
# ClipRange                    0.015
# NumGamma                         4
# Time                       18.5068
# rootSize                   6291.25
# name            12_indoor_hazy.jpg
# Haziness                     0.994
# Name: 1642, dtype: object
# index                         1682
# Dataset          I-HAZY-NTIRE-2018
# Filename                 13_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.009708
# SSIM                      0.673556
# ClipRange                    0.015
# NumGamma                         7
# Time                        26.526
# rootSize                   6291.25
# name            13_indoor_hazy.jpg
# Haziness                     0.993
# Name: 1682, dtype: object
# index                         1721
# Dataset          I-HAZY-NTIRE-2018
# Filename                 14_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.033351
# SSIM                      0.625138
# ClipRange                     0.02
# NumGamma                         3
# Time                       17.0097
# rootSize                   6291.25
# name            14_indoor_hazy.jpg
# Haziness                     0.971
# Name: 1721, dtype: object
# index                         1753
# Dataset          I-HAZY-NTIRE-2018
# Filename                 15_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.013039
# SSIM                      0.738089
# ClipRange                    0.015
# NumGamma                         4
# Time                       18.4743
# rootSize                   6291.25
# name            15_indoor_hazy.jpg
# Haziness                     0.942
# Name: 1753, dtype: object
# index                         1789
# Dataset          I-HAZY-NTIRE-2018
# Filename                 16_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.017333
# SSIM                      0.771801
# ClipRange                    0.015
# NumGamma                         3
# Time                        17.152
# rootSize                   6291.25
# name            16_indoor_hazy.jpg
# Haziness                     0.957
# Name: 1789, dtype: object
# index                         1829
# Dataset          I-HAZY-NTIRE-2018
# Filename                 17_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.024712
# SSIM                      0.443278
# ClipRange                    0.015
# NumGamma                         6
# Time                       21.6579
# rootSize                   6291.25
# name            17_indoor_hazy.jpg
# Haziness                     0.949
# Name: 1829, dtype: object
# index                         1874
# Dataset          I-HAZY-NTIRE-2018
# Filename                 18_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.044569
# SSIM                      0.498984
# ClipRange                     0.02
# NumGamma                         8
# Time                       30.8455
# rootSize                   6291.25
# name            18_indoor_hazy.jpg
# Haziness                     0.996
# Name: 1874, dtype: object
# index                         1908
# Dataset          I-HAZY-NTIRE-2018
# Filename                 19_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.039011
# SSIM                      0.492643
# ClipRange                     0.02
# NumGamma                         5
# Time                       20.1176
# rootSize                   6291.25
# name            19_indoor_hazy.jpg
# Haziness                     0.908
# Name: 1908, dtype: object
# index                         1959
# Dataset          I-HAZY-NTIRE-2018
# Filename                 20_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.013893
# SSIM                      0.507735
# ClipRange                     0.03
# NumGamma                         7
# Time                       26.5861
# rootSize                   6291.25
# name            20_indoor_hazy.jpg
# Haziness                     0.971
# Name: 1959, dtype: object
# index                         1986
# Dataset          I-HAZY-NTIRE-2018
# Filename                 21_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.020432
# SSIM                      0.499768
# ClipRange                    0.025
# NumGamma                         3
# Time                       16.9746
# rootSize                   6291.25
# name            21_indoor_hazy.jpg
# Haziness                     0.924
# Name: 1986, dtype: object
# index                         2017
# Dataset          I-HAZY-NTIRE-2018
# Filename                 22_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.019736
# SSIM                      0.592394
# ClipRange                     0.02
# NumGamma                         3
# Time                       17.0122
# rootSize                   6291.25
# name            22_indoor_hazy.jpg
# Haziness                      0.94
# Name: 2017, dtype: object
# index                         2056
# Dataset          I-HAZY-NTIRE-2018
# Filename                 23_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.033063
# SSIM                      0.667136
# ClipRange                     0.02
# NumGamma                         5
# Time                       20.5031
# rootSize                   6291.25
# name            23_indoor_hazy.jpg
# Haziness                     0.884
# Name: 2056, dtype: object
# index                         2112
# Dataset          I-HAZY-NTIRE-2018
# Filename                 25_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.015191
# SSIM                      0.717505
# ClipRange                    0.005
# NumGamma                         5
# Time                       20.0404
# rootSize                   6291.25
# name            25_indoor_hazy.jpg
# Haziness                     0.968
# Name: 2112, dtype: object
# index                         2137
# Dataset          I-HAZY-NTIRE-2018
# Filename                 25_indoor
# Size(Pixels)              39579843
# Method                        AMEF
# MSE                       0.015578
# SSIM                      0.489276
# ClipRange                    0.025
# NumGamma                         6
# Time                        21.668
# rootSize                   6291.25
# name            25_indoor_hazy.jpg
# Haziness                     0.968
# Name: 2137, dtype: object
# index                         2175
# Dataset          I-HAZY-NTIRE-2018
# Filename                 31_indoor
# Size(Pixels)              38699496
# Method                        AMEF
# MSE                       0.030863
# SSIM                      0.594853
# ClipRange                    0.025
# NumGamma                         7
# Time                       26.3217
# rootSize                   6220.89
# name            31_indoor_hazy.jpg
# Haziness                     0.958
# Name: 2175, dtype: object
# index                         2208
# Dataset          I-HAZY-NTIRE-2018
# Filename                 32_indoor
# Size(Pixels)              35572716
# Method                        AMEF
# MSE                       0.069369
# SSIM                      0.363293
# ClipRange                    0.025
# NumGamma                         3
# Time                       15.2306
# rootSize                   5964.29
# name            32_indoor_hazy.jpg
# Haziness                         1
# Name: 2208, dtype: object
# index                         2250
# Dataset          I-HAZY-NTIRE-2018
# Filename                 33_indoor
# Size(Pixels)              43088136
# Method                        AMEF
# MSE                       0.024117
# SSIM                      0.553853
# ClipRange                    0.025
# NumGamma                         8
# Time                       33.2715
# rootSize                   6564.16
# name            33_indoor_hazy.jpg
# Haziness                     0.816
# Name: 2250, dtype: object
# index                         2296
# Dataset          I-HAZY-NTIRE-2018
# Filename                 35_indoor
# Size(Pixels)              44732016
# Method                        AMEF
# MSE                       0.041043
# SSIM                      0.486181
# ClipRange                    0.005
# NumGamma                         4
# Time                        21.349
# rootSize                    6688.2
# name            35_indoor_hazy.jpg
# Haziness                     0.997
# Name: 2296, dtype: object
# index                         2326
# Dataset          I-HAZY-NTIRE-2018
# Filename                 35_indoor
# Size(Pixels)              44732016
# Method                        AMEF
# MSE                       0.042126
# SSIM                      0.432262
# ClipRange                     0.03
# NumGamma                         4
# Time                       20.8854
# rootSize                    6688.2
# name            35_indoor_hazy.jpg
# Haziness                     0.997
# Name: 2326, dtype: object
# index                          2380
# Dataset           O-HAZY-NTIRE-2018
# Filename                 02_outdoor
# Size(Pixels)               25248696
# Method                         AMEF
# MSE                        0.042682
# SSIM                       0.583789
# ClipRange                      0.01
# NumGamma                          8
# Time                        19.2533
# rootSize                    5024.81
# name            02_outdoor_hazy.jpg
# Haziness                      0.982
# Name: 2380, dtype: object
# index                          2409
# Dataset           O-HAZY-NTIRE-2018
# Filename                 03_outdoor
# Size(Pixels)               59448576
# Method                         AMEF
# MSE                         0.00641
# SSIM                       0.735989
# ClipRange                     0.005
# NumGamma                          6
# Time                        33.0065
# rootSize                    7710.29
# name            03_outdoor_hazy.JPG
# Haziness                     0.9775
# Name: 2409, dtype: object
# index                          2435
# Dataset           O-HAZY-NTIRE-2018
# Filename                 03_outdoor
# Size(Pixels)               59448576
# Method                         AMEF
# MSE                        0.014866
# SSIM                       0.700315
# ClipRange                     0.025
# NumGamma                          8
# Time                         45.134
# rootSize                    7710.29
# name            03_outdoor_hazy.JPG
# Haziness                     0.9775
# Name: 2435, dtype: object
# index                          2478
# Dataset           O-HAZY-NTIRE-2018
# Filename                 04_outdoor
# Size(Pixels)               29956416
# Method                         AMEF
# MSE                        0.016507
# SSIM                       0.446788
# ClipRange                      0.03
# NumGamma                          8
# Time                        22.9787
# rootSize                    5473.25
# name            04_outdoor_hazy.jpg
# Haziness                     0.9695
# Name: 2478, dtype: object
# index                          2518
# Dataset           O-HAZY-NTIRE-2018
# Filename                 06_outdoor
# Size(Pixels)               30951756
# Method                         AMEF
# MSE                        0.030295
# SSIM                       0.339348
# ClipRange                     0.005
# NumGamma                          4
# Time                         14.513
# rootSize                    5563.43
# name            06_outdoor_hazy.jpg
# Haziness                     0.9768
# Name: 2518, dtype: object
# index                          2555
# Dataset           O-HAZY-NTIRE-2018
# Filename                 07_outdoor
# Size(Pixels)               44566866
# Method                         AMEF
# MSE                        0.010409
# SSIM                       0.637467
# ClipRange                     0.005
# NumGamma                          4
# Time                        20.8117
# rootSize                    6675.84
# name            07_outdoor_hazy.jpg
# Haziness                      0.962
# Name: 2555, dtype: object
# index                          2593
# Dataset           O-HAZY-NTIRE-2018
# Filename                 08_outdoor
# Size(Pixels)               25916736
# Method                         AMEF
# MSE                        0.023765
# SSIM                       0.316613
# ClipRange                     0.005
# NumGamma                          5
# Time                         13.655
# rootSize                    5090.85
# name            08_outdoor_hazy.jpg
# Haziness                      0.984
# Name: 2593, dtype: object
# index                          2631
# Dataset           O-HAZY-NTIRE-2018
# Filename                 09_outdoor
# Size(Pixels)               21841596
# Method                         AMEF
# MSE                        0.023285
# SSIM                        0.10566
# ClipRange                     0.005
# NumGamma                          6
# Time                        11.5296
# rootSize                     4673.5
# name            09_outdoor_hazy.jpg
# Haziness                      0.941
# Name: 2631, dtype: object
# index                          2669
# Dataset           O-HAZY-NTIRE-2018
# Filename                 10_outdoor
# Size(Pixels)               18960156
# Method                         AMEF
# MSE                        0.020027
# SSIM                       0.558131
# ClipRange                     0.005
# NumGamma                          7
# Time                        12.7274
# rootSize                    4354.33
# name            10_outdoor_hazy.jpg
# Haziness                     0.9842
# Name: 2669, dtype: object
# index                          2707
# Dataset           O-HAZY-NTIRE-2018
# Filename                 11_outdoor
# Size(Pixels)               30022575
# Method                         AMEF
# MSE                        0.028473
# SSIM                       0.651702
# ClipRange                     0.005
# NumGamma                          8
# Time                        23.3594
# rootSize                    5479.29
# name            11_outdoor_hazy.jpg
# Haziness                     0.9785
# Name: 2707, dtype: object
# index                          2750
# Dataset           O-HAZY-NTIRE-2018
# Filename                 12_outdoor
# Size(Pixels)               33948486
# Method                         AMEF
# MSE                        0.019977
# SSIM                       0.396393
# ClipRange                      0.01
# NumGamma                          8
# Time                          26.68
# rootSize                    5826.53
# name            12_outdoor_hazy.jpg
# Haziness                     0.9568
# Name: 2750, dtype: object
# index                          2813
# Dataset           O-HAZY-NTIRE-2018
# Filename                 14_outdoor
# Size(Pixels)               47642505
# Method                         AMEF
# MSE                        0.013875
# SSIM                       0.463358
# ClipRange                     0.005
# NumGamma                          3
# Time                        20.8082
# rootSize                    6902.36
# name            14_outdoor_hazy.jpg
# Haziness                     0.9782
# Name: 2813, dtype: object
# index                          2824
# Dataset           O-HAZY-NTIRE-2018
# Filename                 14_outdoor
# Size(Pixels)               47642505
# Method                         AMEF
# MSE                        0.028404
# SSIM                       0.460651
# ClipRange                      0.01
# NumGamma                          8
# Time                        36.7618
# rootSize                    6902.36
# name            14_outdoor_hazy.jpg
# Haziness                     0.9782
# Name: 2824, dtype: object
# index                          2865
# Dataset           O-HAZY-NTIRE-2018
# Filename                 15_outdoor
# Size(Pixels)               36721326
# Method                         AMEF
# MSE                        0.023975
# SSIM                       0.272682
# ClipRange                     0.015
# NumGamma                          6
# Time                        20.0258
# rootSize                    6059.81
# name            15_outdoor_hazy.jpg
# Haziness                      0.977
# Name: 2865, dtype: object
# index                          2911
# Dataset           O-HAZY-NTIRE-2018
# Filename                 16_outdoor
# Size(Pixels)               40199040
# Method                         AMEF
# MSE                        0.055892
# SSIM                       0.137277
# ClipRange                     0.025
# NumGamma                          3
# Time                        17.2248
# rootSize                    6340.27
# name            16_outdoor_hazy.jpg
# Haziness                     0.9765
# Name: 2911, dtype: object
# index                          2935
# Dataset           O-HAZY-NTIRE-2018
# Filename                 17_outdoor
# Size(Pixels)               32864454
# Method                         AMEF
# MSE                        0.034817
# SSIM                       0.086138
# ClipRange                      0.01
# NumGamma                          8
# Time                        24.8543
# rootSize                    5732.75
# name            17_outdoor_hazy.jpg
# Haziness                     0.9682
# Name: 2935, dtype: object
# index                          2979
# Dataset           O-HAZY-NTIRE-2018
# Filename                 18_outdoor
# Size(Pixels)               24553656
# Method                         AMEF
# MSE                        0.063293
# SSIM                       0.378591
# ClipRange                      0.02
# NumGamma                          3
# Time                        10.0888
# rootSize                    4955.16
# name            18_outdoor_hazy.jpg
# Haziness                     0.9628
# Name: 2979, dtype: object
# index                          3029
# Dataset           O-HAZY-NTIRE-2018
# Filename                 19_outdoor
# Size(Pixels)               49188096
# Method                         AMEF
# MSE                        0.019346
# SSIM                       0.478868
# ClipRange                      0.03
# NumGamma                          4
# Time                        22.9608
# rootSize                    7013.42
# name            19_outdoor_hazy.jpg
# Haziness                      0.986
# Name: 3029, dtype: object
# index                          3049
# Dataset           O-HAZY-NTIRE-2018
# Filename                 20_outdoor
# Size(Pixels)               41304303
# Method                         AMEF
# MSE                        0.035056
# SSIM                       0.193698
# ClipRange                     0.015
# NumGamma                          5
# Time                        20.9658
# rootSize                    6426.84
# name            20_outdoor_hazy.jpg
# Haziness                     0.9812
# Name: 3049, dtype: object
# index                          3086
# Dataset           O-HAZY-NTIRE-2018
# Filename                 21_outdoor
# Size(Pixels)               59448576
# Method                         AMEF
# MSE                        0.033254
# SSIM                       0.080428
# ClipRange                     0.015
# NumGamma                          5
# Time                        29.8092
# rootSize                    7710.29
# name            21_outdoor_hazy.JPG
# Haziness                      0.978
# Name: 3086, dtype: object
# index                          3125
# Dataset           O-HAZY-NTIRE-2018
# Filename                 22_outdoor
# Size(Pixels)               58362816
# Method                         AMEF
# MSE                        0.013131
# SSIM                       0.606066
# ClipRange                     0.015
# NumGamma                          7
# Time                        39.4614
# rootSize                    7639.56
# name            22_outdoor_hazy.jpg
# Haziness                      0.976
# Name: 3125, dtype: object
# index                          3163
# Dataset           O-HAZY-NTIRE-2018
# Filename                 23_outdoor
# Size(Pixels)               33478125
# Method                         AMEF
# MSE                        0.017333
# SSIM                       0.634047
# ClipRange                     0.015
# NumGamma                          8
# Time                        25.2851
# rootSize                    5786.03
# name            23_outdoor_hazy.jpg
# Haziness                     0.9808
# Name: 3163, dtype: object
# index                          3197
# Dataset           O-HAZY-NTIRE-2018
# Filename                 24_outdoor
# Size(Pixels)               29827476
# Method                         AMEF
# MSE                        0.022744
# SSIM                       0.426302
# ClipRange                     0.015
# NumGamma                          5
# Time                        15.0276
# rootSize                    5461.45
# name            24_outdoor_hazy.jpg
# Haziness                     0.9705
# Name: 3197, dtype: object
# index                          3235
# Dataset           O-HAZY-NTIRE-2018
# Filename                 25_outdoor
# Size(Pixels)               40529016
# Method                         AMEF
# MSE                        0.019441
# SSIM                       0.382147
# ClipRange                     0.015
# NumGamma                          6
# Time                        21.9442
# rootSize                    6366.24
# name            25_outdoor_hazy.jpg
# Haziness                     0.9705
# Name: 3235, dtype: object
# index                          3277
# Dataset           O-HAZY-NTIRE-2018
# Filename                 26_outdoor
# Size(Pixels)               32249016
# Method                         AMEF
# MSE                          0.0268
# SSIM                       0.423547
# ClipRange                      0.02
# NumGamma                          5
# Time                        16.2215
# rootSize                    5678.82
# name            26_outdoor_hazy.jpg
# Haziness                     0.9452
# Name: 3277, dtype: object
# index                          3321
# Dataset           O-HAZY-NTIRE-2018
# Filename                 27_outdoor
# Size(Pixels)               16884936
# Method                         AMEF
# MSE                        0.015054
# SSIM                       0.482723
# ClipRange                     0.025
# NumGamma                          6
# Time                        8.77433
# rootSize                    4109.13
# name            27_outdoor_hazy.jpg
# Haziness                     0.9658
# Name: 3321, dtype: object
# index                          3384
# Dataset           O-HAZY-NTIRE-2018
# Filename                 29_outdoor
# Size(Pixels)               18420336
# Method                         AMEF
# MSE                         0.02082
# SSIM                       0.335255
# ClipRange                     0.015
# NumGamma                          7
# Time                        11.1913
# rootSize                    4291.89
# name            29_outdoor_hazy.jpg
# Haziness                      0.936
# Name: 3384, dtype: object
# index                          3403
# Dataset           O-HAZY-NTIRE-2018
# Filename                 29_outdoor
# Size(Pixels)               18420336
# Method                         AMEF
# MSE                        0.019146
# SSIM                       0.333442
# ClipRange                      0.03
# NumGamma                          8
# Time                        14.0883
# rootSize                    4291.89
# name            29_outdoor_hazy.jpg
# Haziness                      0.936
# Name: 3403, dtype: object
# index                          3454
# Dataset           O-HAZY-NTIRE-2018
# Filename                 31_outdoor
# Size(Pixels)               23993736
# Method                         AMEF
# MSE                        0.012668
# SSIM                        0.62238
# ClipRange                     0.015
# NumGamma                          3
# Time                        9.78475
# rootSize                    4898.34
# name            31_outdoor_hazy.jpg
# Haziness                     0.9632
# Name: 3454, dtype: object
# index                          3498
# Dataset           O-HAZY-NTIRE-2018
# Filename                 32_outdoor
# Size(Pixels)               40700160
# Method                         AMEF
# MSE                        0.010095
# SSIM                       0.629232
# ClipRange                      0.02
# NumGamma                          4
# Time                        18.9328
# rootSize                    6379.67
# name            32_outdoor_hazy.jpg
# Haziness                     0.9678
# Name: 3498, dtype: object
# index                          3506
# Dataset           O-HAZY-NTIRE-2018
# Filename                 32_outdoor
# Size(Pixels)               40700160
# Method                         AMEF
# MSE                         0.01471
# SSIM                       0.601461
# ClipRange                     0.025
# NumGamma                          6
# Time                         22.118
# rootSize                    6379.67
# name            32_outdoor_hazy.jpg
# Haziness                     0.9678
# Name: 3506, dtype: object
# index                          3545
# Dataset           O-HAZY-NTIRE-2018
# Filename                 33_outdoor
# Size(Pixels)               47181936
# Method                         AMEF
# MSE                        0.024277
# SSIM                       0.446536
# ClipRange                     0.025
# NumGamma                          8
# Time                        35.9207
# rootSize                    6868.91
# name            33_outdoor_hazy.jpg
# Haziness                     0.9502
# Name: 3545, dtype: object
# index                          3576
# Dataset           O-HAZY-NTIRE-2018
# Filename                 34_outdoor
# Size(Pixels)               58904496
# Method                         AMEF
# MSE                        0.020295
# SSIM                       0.498578
# ClipRange                      0.02
# NumGamma                          8
# Time                        48.0635
# rootSize                    7674.93
# name            34_outdoor_hazy.jpg
# Haziness                      0.987
# Name: 3576, dtype: object
# index                          3618
# Dataset           O-HAZY-NTIRE-2018
# Filename                 35_outdoor
# Size(Pixels)                3653526
# Method                         AMEF
# MSE                        0.013874
# SSIM                       0.699536
# ClipRange                     0.025
# NumGamma                          7
# Time                        2.33856
# rootSize                    1911.42
# name            35_outdoor_hazy.jpg
# Haziness                     0.9605
# Name: 3618, dtype: object
# index                          3655
# Dataset           O-HAZY-NTIRE-2018
# Filename                 36_outdoor
# Size(Pixels)               37880826
# Method                         AMEF
# MSE                        0.013757
# SSIM                        0.59113
# ClipRange                     0.025
# NumGamma                          7
# Time                         25.078
# rootSize                    6154.74
# name            36_outdoor_hazy.jpg
# Haziness                     0.9755
# Name: 3655, dtype: object
# index                          3693
# Dataset           O-HAZY-NTIRE-2018
# Filename                 37_outdoor
# Size(Pixels)               32878098
# Method                         AMEF
# MSE                        0.016067
# SSIM                       0.573552
# ClipRange                     0.025
# NumGamma                          8
# Time                        24.5874
# rootSize                    5733.94
# name            37_outdoor_hazy.jpg
# Haziness                      0.984
# Name: 3693, dtype: object
# index                          3738
# Dataset           O-HAZY-NTIRE-2018
# Filename                 39_outdoor
# Size(Pixels)               33387816
# Method                         AMEF
# MSE                        0.027925
# SSIM                       0.450516
# ClipRange                     0.005
# NumGamma                          3
# Time                        14.0189
# rootSize                    5778.22
# name            39_outdoor_hazy.jpg
# Haziness                      0.966
# Name: 3738, dtype: object
# index                          3771
# Dataset           O-HAZY-NTIRE-2018
# Filename                 39_outdoor
# Size(Pixels)               33387816
# Method                         AMEF
# MSE                        0.022554
# SSIM                       0.489933
# ClipRange                      0.03
# NumGamma                          6
# Time                        18.6925
# rootSize                    5778.22
# name            39_outdoor_hazy.jpg
# Haziness                      0.966
# Name: 3771, dtype: object
# index                          3816
# Dataset           O-HAZY-NTIRE-2018
# Filename                 41_outdoor
# Size(Pixels)               21411876
# Method                         AMEF
# MSE                        0.030747
# SSIM                       0.477913
# ClipRange                     0.005
# NumGamma                          7
# Time                        13.5384
# rootSize                     4627.3
# name            41_outdoor_hazy.jpg
# Haziness                     0.9728
# Name: 3816, dtype: object
# index                          3863
# Dataset           O-HAZY-NTIRE-2018
# Filename                 42_outdoor
# Size(Pixels)               41517216
# Method                         AMEF
# MSE                        0.028402
# SSIM                       0.349538
# ClipRange                     0.015
# NumGamma                          5
# Time                        20.8219
# rootSize                    6443.39
# name            42_outdoor_hazy.jpg
# Haziness                     0.9715
# Name: 3863, dtype: object
# index                          3906
# Dataset           O-HAZY-NTIRE-2018
# Filename                 43_outdoor
# Size(Pixels)               48731376
# Method                         AMEF
# MSE                        0.011133
# SSIM                       0.587429
# ClipRange                      0.02
# NumGamma                          5
# Time                        24.1933
# rootSize                    6980.79
# name            43_outdoor_hazy.jpg
# Haziness                     0.9722
# Name: 3906, dtype: object
# index                          3918
# Dataset           O-HAZY-NTIRE-2018
# Filename                 43_outdoor
# Size(Pixels)               48731376
# Method                         AMEF
# MSE                        0.014781
# SSIM                       0.543261
# ClipRange                      0.03
# NumGamma                          5
# Time                        24.2442
# rootSize                    6980.79
# name            43_outdoor_hazy.jpg
# Haziness                     0.9722
# Name: 3918, dtype: object
# index                          3962
# Dataset           O-HAZY-NTIRE-2018
# Filename                 45_outdoor
# Size(Pixels)               28850976
# Method                         AMEF
# MSE                        0.023309
# SSIM                       0.256998
# ClipRange                     0.005
# NumGamma                          5
# Time                         14.276
# rootSize                    5371.31
# name            45_outdoor_hazy.jpg
# Haziness                     0.9532
# Name: 3962, dtype: object
# index                          3995
# Dataset           O-HAZY-NTIRE-2018
# Filename                 45_outdoor
# Size(Pixels)               28850976
# Method                         AMEF
# MSE                        0.022074
# SSIM                       0.444327
# ClipRange                      0.03
# NumGamma                          8
# Time                         21.373
# rootSize                    5371.31
# name            45_outdoor_hazy.jpg
# Haziness                     0.9532
# Name: 3995, dtype: object
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-99-20e93e31a722> in <module>
#      13
#      14     if nameCurr != namePrev and started:
# ---> 15         hzMSE = hzMSE.append(data_dehazed.iloc[bestMSE], ignore_index=True)
#      16 #         hzSSIM = pd.concat([hzSSIM,data_dehazed.iloc[bestSSIM]])
#      17         print(data_dehazed.iloc[bestMSE])
#
# c:\users\dansh\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# c:\users\dansh\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1494
#    1495             # validate the location
# -> 1496             self._validate_integer(key, axis)
#    1497
#    1498             return self.obj._ixs(key, axis=axis)
#
# c:\users\dansh\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1435         len_axis = len(self.obj._get_axis(axis))
#    1436         if key >= len_axis or key < -len_axis:
# -> 1437             raise IndexError("single positional indexer is out-of-bounds")
#    1438
#    1439     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
hzMSE.head()
# Out:
#                            0 ClipRange Dataset Filename  MSE Method NumGamma  \
# index                      6       NaN     NaN      NaN  NaN    NaN      NaN
# Dataset           D-HAZY-MID       NaN     NaN      NaN  NaN    NaN      NaN
# Filename      Adirondack_im0       NaN     NaN      NaN  NaN    NaN      NaN
# Size(Pixels)        17176320       NaN     NaN      NaN  NaN    NaN      NaN
# Method                  AMEF       NaN     NaN      NaN  NaN    NaN      NaN
#
#              SSIM Size(Pixels) Time
# index         NaN          NaN  NaN
# Dataset       NaN          NaN  NaN
# Filename      NaN          NaN  NaN
# Size(Pixels)  NaN          NaN  NaN
# Method        NaN          NaN  NaN
